# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
import random as rd
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim
import math
from folium.plugins import MarkerCluster

# %%
def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')

# %% [markdown]
# ### Geocode the missing locations

# %%
starbucks = pd.read_csv("../../geospatial-learn-course-data/starbucks_locations.csv")
# print(starbucks.isnull().sum())
rows_with_missing = starbucks.loc[starbucks["City"] == "Berkeley"]
display(rows_with_missing)
# Out:
#      Store Number                Store Name  \
# 153      5406-945  2224 Shattuck - Berkeley
# 154       570-512                Solano Ave
# 155  17877-164526   Safeway - Berkeley #691
# 156  19864-202264         Telegraph & Ashby
# 157     9217-9253           2128 Oxford St.
#
#                                Address      City  Longitude  Latitude
# 153   2224 Shattuck Avenue Berkeley CA  Berkeley        NaN       NaN
# 154     1799 Solano Avenue Berkeley CA  Berkeley        NaN       NaN
# 155    1444 Shattuck Place Berkeley CA  Berkeley        NaN       NaN
# 156  3001 Telegraph Avenue Berkeley CA  Berkeley        NaN       NaN
# 157     2128 Oxford Street Berkeley CA  Berkeley        NaN       NaN

# %%
geolocator = Nominatim(user_agent="exercice-kaggle-course")
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

rows_with_missing[["Latitude", "Longitude"]] = rows_with_missing.apply(lambda x:my_geocoder(x["Address"]), axis=1)

# %% [markdown]
# ### View Berkeley location

# %%
def showMap(data):
    mc = MarkerCluster()
    map = folium.Map(location=[37.88,-122.26], tiles='openstreetmap', zoom_start=13)
    for _, row in data.iterrows():
        color = f"rgb({rd.randint(0, 255)}, {rd.randint(0, 255)}, {rd.randint(0, 255)})"
        icons = ['fa-ice-cream', 'fa-coffee','fa-beer','fa-cocktail','fa-apple-alt']
        icon = rd.choice(icons)
        if not math.isnan(row['Longitude']) and not math.isnan(row['Latitude']):
            mc.add_child(folium.Marker(location=[row["Latitude"], row["Longitude"]], icon=folium.Icon(color=color, icon=icon, prefix='fa')))
    map.add_child(mc)
    return map
showMap(rows_with_missing)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_becd98936379b463e29257bec71e71a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_becd98936379b463e29257bec71e71a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_becd98936379b463e29257bec71e71a3 = L.map(
#                 &quot;map_becd98936379b463e29257bec71e71a3&quot;,
#                 {
#                     center: [37.88, -122.26],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deef8353257b00b0ee72836268d5e78e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deef8353257b00b0ee72836268d5e78e.addTo(map_becd98936379b463e29257bec71e71a3);
#
#
#             var marker_cluster_3f29d6a4762e8100ff2caeda81b0e715 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b5337334e9c0a899a720d8fd1c0d9412 = L.marker(
#                 [37.8688395, -122.26823],
#                 {
# }
#             ).addTo(marker_cluster_3f29d6a4762e8100ff2caeda81b0e715);
#
#
#             var icon_11923a488d4cd7830d55b99bb6947dc3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(194, 212, 160)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-beer&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_b5337334e9c0a899a720d8fd1c0d9412.setIcon(icon_11923a488d4cd7830d55b99bb6947dc3);
#
#
#             var marker_5618e680351afa63cb2e0b269b5a2fcc = L.marker(
#                 [37.891477, -122.280013],
#                 {
# }
#             ).addTo(marker_cluster_3f29d6a4762e8100ff2caeda81b0e715);
#
#
#             var icon_efe6a9771655f1b79325e45c7e4e073c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(135, 132, 177)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-apple-alt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5618e680351afa63cb2e0b269b5a2fcc.setIcon(icon_efe6a9771655f1b79325e45c7e4e073c);
#
#
#             var marker_1e7cfbc452b802403c142b1b20243f5c = L.marker(
#                 [37.8809073, -122.2696792],
#                 {
# }
#             ).addTo(marker_cluster_3f29d6a4762e8100ff2caeda81b0e715);
#
#
#             var icon_7951bafb3161fbfe32e98ee5abb7b613 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(224, 233, 67)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-apple-alt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1e7cfbc452b802403c142b1b20243f5c.setIcon(icon_7951bafb3161fbfe32e98ee5abb7b613);
#
#
#             var marker_08b922f320237e27833697169947df00 = L.marker(
#                 [37.855903, -122.25940593816131],
#                 {
# }
#             ).addTo(marker_cluster_3f29d6a4762e8100ff2caeda81b0e715);
#
#
#             var icon_e93364b76fd246914e36b3e6bed1741b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(216, 48, 117)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-apple-alt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_08b922f320237e27833697169947df00.setIcon(icon_e93364b76fd246914e36b3e6bed1741b);
#
#
#             var marker_7bfbbbef0957110e76c7adc4879c7bb3 = L.marker(
#                 [37.870253149999996, -122.26609492936619],
#                 {
# }
#             ).addTo(marker_cluster_3f29d6a4762e8100ff2caeda81b0e715);
#
#
#             var icon_26427748f78de2735ae781a7dc837d95 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(151, 147, 197)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-cocktail&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7bfbbbef0957110e76c7adc4879c7bb3.setIcon(icon_26427748f78de2735ae781a7dc837d95);
#
#
#             marker_cluster_3f29d6a4762e8100ff2caeda81b0e715.addTo(map_becd98936379b463e29257bec71e71a3);

# %% [markdown]
# ###  Consolidate your data

# %%
CA_counties = gpd.read_file("../../geospatial-learn-course-data/CA_county_boundaries/CA_county_boundaries/CA_county_boundaries.shp")
CA_counties.crs = {'init': 'epsg:4326'}
CA_pop = pd.read_csv("../../geospatial-learn-course-data/CA_county_population.csv", index_col="GEOID")
CA_high_earners = pd.read_csv("../../geospatial-learn-course-data/CA_county_high_earners.csv", index_col="GEOID")
CA_median_age = pd.read_csv("../../geospatial-learn-course-data/CA_county_median_age.csv", index_col="GEOID")

CA_counties = CA_counties.merge(CA_pop, on="GEOID")
CA_counties = CA_counties.merge(CA_high_earners, on="GEOID")
CA_stats = CA_counties.merge(CA_median_age,on="GEOID")

# %%
CA_stats["density"] = CA_stats["population"] / CA_stats["area_sqkm"]

# %% [markdown]
# ### Which counties look promising ?

# %%
sel_counties = CA_stats.loc[((CA_stats["median_age"] < 38.5) & (CA_stats["density"] > 285) & (CA_stats["high_earners"] >100000) & ((CA_stats["median_age"] < 35.5) | (CA_stats["density"] > 1400) | (CA_stats["high_earners"] >500000)))]

# %% [markdown]
# ### How many stores did you identify?

# %%
starbucks_gdf = gpd.GeoDataFrame(starbucks, geometry=gpd.points_from_xy(starbucks.Longitude, starbucks.Latitude))
starbucks_gdf.crs = {'init': 'epsg:4326'}

locations_of_interest= gpd.sjoin(starbucks_gdf, sel_counties)
num_stores = len(locations_of_interest)
print(num_stores)
# Out:
# 1043

# %% [markdown]
# ### Visualize the store locations.

# %%
map = folium.Map(location=[37,-120], tiles='openstreetmap', zoom_start=6)
showMap(locations_of_interest)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a564ebd720b142404fd6c5eb3f0aaf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a564ebd720b142404fd6c5eb3f0aaf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a564ebd720b142404fd6c5eb3f0aaf2 = L.map(
#                 &quot;map_5a564ebd720b142404fd6c5eb3f0aaf2&quot;,
#                 {
#                     center: [37.88, -122.26],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_872df10faab4dec6ff1d7fa9f2d45c06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_872df10faab4dec6ff1d7fa9f2d45c06.addTo(map_5a564ebd720b142404fd6c5eb3f0aaf2);
#
#
#             var marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e3c8998eafbba4fc6b6e0070a514e2f1 = L.marker(
#                 [34.16, -118.76],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f);
#
#
#             var icon_a04e656a69edca35e1e792cdf0ca0902 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(226, 35, 87)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-cocktail&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e3c8998eafbba4fc6b6e0070a514e2f1.setIcon(icon_a04e656a69edca35e1e792cdf0ca0902);
#
#
#             var marker_f4773af081ae011d78b067d2d491729c = L.marker(
#                 [34.15, -118.76],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f);
#
#
#             var icon_23769e450dad1ae13f684394a512f2e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(223, 141, 18)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-apple-alt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f4773af081ae011d78b067d2d491729c.setIcon(icon_23769e450dad1ae13f684394a512f2e0);
#
#
#             var marker_44897329b0e1e3d2eb0933ef43e5f4be = L.marker(
#                 [34.09, -118.14],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f);
#
#
#             var icon_0b55d933eeb5371ebd40f1b4c4f19f09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(169, 241, 197)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-cocktail&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_44897329b0e1e3d2eb0933ef43e5f4be.setIcon(icon_0b55d933eeb5371ebd40f1b4c4f19f09);
#
#
#             var marker_a9bc8e5c69bb566e8b32f5fd3f82725a = L.marker(
#                 [34.08, -118.15],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f);
#
#
#             var icon_ab7fe2ad59e877fe557240828b18ac0e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(62, 214, 78)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-beer&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a9bc8e5c69bb566e8b32f5fd3f82725a.setIcon(icon_ab7fe2ad59e877fe557240828b18ac0e);
#
#
#             var marker_3f88a5924f2565eacb3dfb94bf2c9b2d = L.marker(
#                 [34.08, -118.13],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1721f);
#
#
#             var icon_d6a0851fd6aaba0814f007e70e11d66d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;rgb(135, 216, 224)&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-beer&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3f88a5924f2565eacb3dfb94bf2c9b2d.setIcon(icon_d6a0851fd6aaba0814f007e70e11d66d);
#
#
#             var marker_4fc5cfa4a84cba1d0fcce02406a90d77 = L.marker(
#                 [34.09, -118.15],
#                 {
# }
#             ).addTo(marker_cluster_5e75a2bf2cbba9504c5d91b860c1
